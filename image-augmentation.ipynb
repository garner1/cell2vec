# %%
import numpy as np
import os
import random
from scipy import ndarray

# image processing library
import skimage as sk
from skimage import transform
from skimage import util
from skimage import io
import imageio

# %%
def random_rotation(image_array):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree)

def rotation(image_array, degree):
    return sk.transform.rotate(image_array, degree)

def random_noise(image_array):
    # add random noise to the image
    return sk.util.random_noise(image_array)

def horizontal_flip(image_array):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]

    return rmin, rmax, cmin, cmax    

def pad_with(vector, pad_width, iaxis, kwargs):
    pad_value = kwargs.get('padder', 0)
    vector[:pad_width[0]] = pad_value
    vector[-pad_width[1]:] = pad_value

# %%
'''Generate for each of the unique 200 cell type, 
all rotated and flipped copies'''

folder_path = '/home/garner1/Work/dataset/cellImages/training/Cancer'
augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training/augmented/Cancer'
num_unique_cells = 200

images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

for num_processed_cell in range(num_unique_cells):
    path = '%s/cell_%s' % (augmented_folder_path,num_processed_cell)
    if not os.path.isdir(path): 
        os.mkdir(path)
    else:
        pass
    
for num_processed_cell in range(num_unique_cells):
#     print('Augmenting cancer cell '+str(num_processed_cell))
    image_path = images[num_processed_cell]
    image_path = imageio.imread(image_path)
    rmin, rmax, cmin, cmax = bbox(image_path)
    image_to_transform = np.pad(image_path[rmin:rmax,cmin:cmax], 2, pad_with, padder=0)  
    
    rotation_angle = 0
    transformed_image = None
    while rotation_angle <= 360:
        transformed_image = rotation(image_to_transform, rotation_angle)
        new_file_path = '%s/cell_%s/angle_%s.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
        io.imsave(new_file_path, transformed_image)
        transformed_image = horizontal_flip(transformed_image)
        new_file_path = '%s/cell_%s/angle_%s_flipped.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
        io.imsave(new_file_path, transformed_image)
        rotation_angle += 1
    
folder_path = '/home/garner1/Work/dataset/cellImages/training/Immuno'
augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training/augmented/Immuno'
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

for num_processed_cell in range(num_unique_cells):
    path = '%s/cell_%s' % (augmented_folder_path,num_processed_cell)
    if not os.path.isdir(path): 
        os.mkdir(path)
    else:
        pass

for num_processed_cell in range(num_unique_cells):
#     print('Augmenting immuno cell '+str(num_processed_cell))
    image_path = images[num_processed_cell]
    image_path = imageio.imread(image_path)
    rmin, rmax, cmin, cmax = bbox(image_path)
    image_to_transform = np.pad(image_path[rmin:rmax,cmin:cmax], 2, pad_with, padder=0)  
    
    rotation_angle = 0
    transformed_image = None
    while rotation_angle <= 360:
        transformed_image = rotation(image_to_transform, rotation_angle)
        new_file_path = '%s/cell_%s/angle_%s.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
        io.imsave(new_file_path, transformed_image)
        transformed_image = horizontal_flip(transformed_image)
        new_file_path = '%s/cell_%s/angle_%s_flipped.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
        io.imsave(new_file_path, transformed_image)
        rotation_angle += 1
    
folder_path = '/home/garner1/Work/dataset/cellImages/training/Other'
augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training/augmented/Other'
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

for num_processed_cell in range(num_unique_cells):
    path = '%s/cell_%s' % (augmented_folder_path,num_processed_cell)
    if not os.path.isdir(path): 
        os.mkdir(path)
    else:
        pass

for num_processed_cell in range(num_unique_cells):
#     print('Augmenting other cell '+str(num_processed_cell))
    image_path = images[num_processed_cell]
    image_path = imageio.imread(image_path)
    rmin, rmax, cmin, cmax = bbox(image_path)
    image_to_transform = np.pad(image_path[rmin:rmax,cmin:cmax], 2, pad_with, padder=0)  
    
    rotation_angle = 0
    transformed_image = None
    while rotation_angle <= 360:
        transformed_image = rotation(image_to_transform, rotation_angle)
        new_file_path = '%s/cell_%s/angle_%s.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
        io.imsave(new_file_path, transformed_image)
        transformed_image = horizontal_flip(transformed_image)
        new_file_path = '%s/cell_%s/angle_%s_flipped.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
        io.imsave(new_file_path, transformed_image)
        rotation_angle += 1
# Out:
# Augmenting cell 0
# Augmenting cell 1
# Augmenting cell 2
# Augmenting cell 3
# Augmenting cell 4
# Augmenting cell 5
# Augmenting cell 6
# Augmenting cell 7
# Augmenting cell 8
# Augmenting cell 9
# Augmenting cell 10
# Augmenting cell 11
# Augmenting cell 12
# Augmenting cell 13
# Augmenting cell 14
# Augmenting cell 15
# Augmenting cell 16
# Augmenting cell 17
# Augmenting cell 18
# Augmenting cell 19
# Augmenting cell 20
# Augmenting cell 21
# Augmenting cell 22
# Augmenting cell 23
# Augmenting cell 24
# Augmenting cell 25
# Augmenting cell 26
# Augmenting cell 27
# Augmenting cell 28
# Augmenting cell 29
# Augmenting cell 30
# Augmenting cell 31
# Augmenting cell 32
# Augmenting cell 33
# Augmenting cell 34
# Augmenting cell 35
# Augmenting cell 36
# Augmenting cell 37
# Augmenting cell 38
# Augmenting cell 39
# Augmenting cell 40
# Augmenting cell 41
# Augmenting cell 42
# Augmenting cell 43
# Augmenting cell 44
# Augmenting cell 45
# Augmenting cell 46
# Augmenting cell 47
# Augmenting cell 48
# Augmenting cell 49
# Augmenting cell 50
# Augmenting cell 51
# Augmenting cell 52
# Augmenting cell 53
# Augmenting cell 54
# Augmenting cell 55
# Augmenting cell 56
# Augmenting cell 57
# Augmenting cell 58
# Augmenting cell 59
# Augmenting cell 60
# Augmenting cell 61
# Augmenting cell 62
# Augmenting cell 63
# Augmenting cell 64
# Augmenting cell 65
# Augmenting cell 66
# Augmenting cell 67
# Augmenting cell 68
# Augmenting cell 69
# Augmenting cell 70
# Augmenting cell 71
# Augmenting cell 72
# Augmenting cell 73
# Augmenting cell 74
# Augmenting cell 75
# Augmenting cell 76
# Augmenting cell 77
# Augmenting cell 78
# Augmenting cell 79
# Augmenting cell 80
# Augmenting cell 81
# Augmenting cell 82
# Augmenting cell 83
# Augmenting cell 84
# Augmenting cell 85
# Augmenting cell 86
# Augmenting cell 87
# Augmenting cell 88
# Augmenting cell 89
# Augmenting cell 90
# Augmenting cell 91
# Augmenting cell 92
# Augmenting cell 93
# Augmenting cell 94
# Augmenting cell 95
# Augmenting cell 96
# Augmenting cell 97
# Augmenting cell 98
# Augmenting cell 99
# Augmenting cell 100
# Augmenting cell 101
# Augmenting cell 102
# Augmenting cell 103
# Augmenting cell 104
# Augmenting cell 105
# Augmenting cell 106
# Augmenting cell 107
# Augmenting cell 108
# Augmenting cell 109
# Augmenting cell 110
# Augmenting cell 111
# Augmenting cell 112
# Augmenting cell 113
# Augmenting cell 114
# Augmenting cell 115
# Augmenting cell 116
# Augmenting cell 117
# Augmenting cell 118
# Augmenting cell 119
# Augmenting cell 120
# Augmenting cell 121
# Augmenting cell 122
# Augmenting cell 123
# Augmenting cell 124
# Augmenting cell 125
# Augmenting cell 126
# Augmenting cell 127
# Augmenting cell 128
# Augmenting cell 129
# Augmenting cell 130
# Augmenting cell 131
# Augmenting cell 132
# Augmenting cell 133
# Augmenting cell 134
# Augmenting cell 135
# Augmenting cell 136
# Augmenting cell 137
# Augmenting cell 138
# Augmenting cell 139
# Augmenting cell 140
# Augmenting cell 141
# Augmenting cell 142
# Augmenting cell 143
# Augmenting cell 144
# Augmenting cell 145
# Augmenting cell 146
# Augmenting cell 147
# Augmenting cell 148
# Augmenting cell 149
# Augmenting cell 150
# Augmenting cell 151
# Augmenting cell 152
# Augmenting cell 153
# Augmenting cell 154
# Augmenting cell 155
# Augmenting cell 156
# Augmenting cell 157
# Augmenting cell 158
# Augmenting cell 159
# Augmenting cell 160
# Augmenting cell 161
# Augmenting cell 162
# Augmenting cell 163
# Augmenting cell 164
# Augmenting cell 165
# Augmenting cell 166
# Augmenting cell 167
# Augmenting cell 168
# Augmenting cell 169
# Augmenting cell 170
# Augmenting cell 171
# Augmenting cell 172
# Augmenting cell 173
# Augmenting cell 174
# Augmenting cell 175
# Augmenting cell 176
# Augmenting cell 177
# Augmenting cell 178
# Augmenting cell 179
# Augmenting cell 180
# Augmenting cell 181
# Augmenting cell 182
# Augmenting cell 183
# Augmenting cell 184
# Augmenting cell 185
# Augmenting cell 186
# Augmenting cell 187
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Cancer/cell_187/angle_3.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Cancer/cell_187/angle_3_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Cancer/cell_187/angle_93.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Cancer/cell_187/angle_93_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Cancer/cell_187/angle_183.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Cancer/cell_187/angle_183_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Cancer/cell_187/angle_273.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Cancer/cell_187/angle_273_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Augmenting cell 188
# Augmenting cell 189
# Augmenting cell 190
# Augmenting cell 191
# Augmenting cell 192
# Augmenting cell 193
# Augmenting cell 194
# Augmenting cell 195
# Augmenting cell 196
# Augmenting cell 197
# Augmenting cell 198
# Augmenting cell 199
# Augmenting cell 0
# Augmenting cell 1
# Augmenting cell 2
# Augmenting cell 3
# Augmenting cell 4
# Augmenting cell 5
# Augmenting cell 6
# Augmenting cell 7
# Augmenting cell 8
# Augmenting cell 9
# Augmenting cell 10
# Augmenting cell 11
# Augmenting cell 12
# Augmenting cell 13
# Augmenting cell 14
# Augmenting cell 15
# Augmenting cell 16
# Augmenting cell 17
# Augmenting cell 18
# Augmenting cell 19
# Augmenting cell 20
# Augmenting cell 21
# Augmenting cell 22
# Augmenting cell 23
# Augmenting cell 24
# Augmenting cell 25
# Augmenting cell 26
# Augmenting cell 27
# Augmenting cell 28
# Augmenting cell 29
# Augmenting cell 30
# Augmenting cell 31
# Augmenting cell 32
# Augmenting cell 33
# Augmenting cell 34
# Augmenting cell 35
# Augmenting cell 36
# Augmenting cell 37
# Augmenting cell 38
# Augmenting cell 39
# Augmenting cell 40
# Augmenting cell 41
# Augmenting cell 42
# Augmenting cell 43
# Augmenting cell 44
# Augmenting cell 45
# Augmenting cell 46
# Augmenting cell 47
# Augmenting cell 48
# Augmenting cell 49
# Augmenting cell 50
# Augmenting cell 51
# Augmenting cell 52
# Augmenting cell 53
# Augmenting cell 54
# Augmenting cell 55
# Augmenting cell 56
# Augmenting cell 57
# Augmenting cell 58
# Augmenting cell 59
# Augmenting cell 60
# Augmenting cell 61
# Augmenting cell 62
# Augmenting cell 63
# Augmenting cell 64
# Augmenting cell 65
# Augmenting cell 66
# Augmenting cell 67
# Augmenting cell 68
# Augmenting cell 69
# Augmenting cell 70
# Augmenting cell 71
# Augmenting cell 72
# Augmenting cell 73
# Augmenting cell 74
# Augmenting cell 75
# Augmenting cell 76
# Augmenting cell 77
# Augmenting cell 78
# Augmenting cell 79
# Augmenting cell 80
# Augmenting cell 81
# Augmenting cell 82
# Augmenting cell 83
# Augmenting cell 84
# Augmenting cell 85
# Augmenting cell 86
# Augmenting cell 87
# Augmenting cell 88
# Augmenting cell 89
# Augmenting cell 90
# Augmenting cell 91
# Augmenting cell 92
# Augmenting cell 93
# Augmenting cell 94
# Augmenting cell 95
# Augmenting cell 96
# Augmenting cell 97
# Augmenting cell 98
# Augmenting cell 99
# Augmenting cell 100
# Augmenting cell 101
# Augmenting cell 102
# Augmenting cell 103
# Augmenting cell 104
# Augmenting cell 105
# Augmenting cell 106
# Augmenting cell 107
# Augmenting cell 108
# Augmenting cell 109
# Augmenting cell 110
# Augmenting cell 111
# Augmenting cell 112
# Augmenting cell 113
# Augmenting cell 114
# Augmenting cell 115
# Augmenting cell 116
# Augmenting cell 117
# Augmenting cell 118
# Augmenting cell 119
# Augmenting cell 120
# Augmenting cell 121
# Augmenting cell 122
# Augmenting cell 123
# Augmenting cell 124
# Augmenting cell 125
# Augmenting cell 126
# Augmenting cell 127
# Augmenting cell 128
# Augmenting cell 129
# Augmenting cell 130
# Augmenting cell 131
# Augmenting cell 132
# Augmenting cell 133
# Augmenting cell 134
# Augmenting cell 135
# Augmenting cell 136
# Augmenting cell 137
# Augmenting cell 138
# Augmenting cell 139
# Augmenting cell 140
# Augmenting cell 141
# Augmenting cell 142
# Augmenting cell 143
# Augmenting cell 144
# Augmenting cell 145
# Augmenting cell 146
# Augmenting cell 147
# Augmenting cell 148
# Augmenting cell 149
# Augmenting cell 150
# Augmenting cell 151
# Augmenting cell 152
# Augmenting cell 153
# Augmenting cell 154
# Augmenting cell 155
# Augmenting cell 156
# Augmenting cell 157
# Augmenting cell 158
# Augmenting cell 159
# Augmenting cell 160
# Augmenting cell 161
# Augmenting cell 162
# Augmenting cell 163
# Augmenting cell 164
# Augmenting cell 165
# Augmenting cell 166
# Augmenting cell 167
# Augmenting cell 168
# Augmenting cell 169
# Augmenting cell 170
# Augmenting cell 171
# Augmenting cell 172
# Augmenting cell 173
# Augmenting cell 174
# Augmenting cell 175
# Augmenting cell 176
# Augmenting cell 177
# Augmenting cell 178
# Augmenting cell 179
# Augmenting cell 180
# Augmenting cell 181
# Augmenting cell 182
# Augmenting cell 183
# Augmenting cell 184
# Augmenting cell 185
# Augmenting cell 186
# Augmenting cell 187
# Augmenting cell 188
# Augmenting cell 189
# Augmenting cell 190
# Augmenting cell 191
# Augmenting cell 192
# Augmenting cell 193
# Augmenting cell 194
# Augmenting cell 195
# Augmenting cell 196
# Augmenting cell 197
# Augmenting cell 198
# Augmenting cell 199
# Augmenting cell 0
# Augmenting cell 1
# Augmenting cell 2
# Augmenting cell 3
# Augmenting cell 4
# Augmenting cell 5
# Augmenting cell 6
# Augmenting cell 7
# Augmenting cell 8
# Augmenting cell 9
# Augmenting cell 10
# Augmenting cell 11
# Augmenting cell 12
# Augmenting cell 13
# Augmenting cell 14
# Augmenting cell 15
# Augmenting cell 16
# Augmenting cell 17
# Augmenting cell 18
# Augmenting cell 19
# Augmenting cell 20
# Augmenting cell 21
# Augmenting cell 22
# Augmenting cell 23
# Augmenting cell 24
# Augmenting cell 25
# Augmenting cell 26
# Augmenting cell 27
# Augmenting cell 28
# Augmenting cell 29
# Augmenting cell 30
# Augmenting cell 31
# Augmenting cell 32
# Augmenting cell 33
# Augmenting cell 34
# Augmenting cell 35
# Augmenting cell 36
# Augmenting cell 37
# Augmenting cell 38
# Augmenting cell 39
# Augmenting cell 40
# Augmenting cell 41
# Augmenting cell 42
# Augmenting cell 43
# Augmenting cell 44
# Augmenting cell 45
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_0.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_0_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_1.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_1_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_2.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_2_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_3.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_3_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_4.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_4_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_5.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_5_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_6.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_6_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_7.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_7_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_8.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_8_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_9.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_9_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_10.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_10_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_11.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_11_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_12.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_12_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_13.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_13_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_14.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_14_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_15.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_15_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_16.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_16_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_17.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_17_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_18.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_18_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_19.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_19_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_20.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_20_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_21.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_21_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_22.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_22_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_23.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_23_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_24.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_24_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_25.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_25_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_26.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_26_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_27.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_27_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_28.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_28_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_29.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_29_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_30.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_30_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_31.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_31_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_32.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_32_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_33.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_33_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_34.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_34_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_35.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_35_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_36.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_36_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_37.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_37_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_38.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_38_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_39.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_39_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_40.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_40_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_41.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_41_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_42.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_42_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_43.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_43_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_44.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_44_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_45.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_45_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_46.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_46_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_47.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_47_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_48.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_48_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_49.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_49_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_50.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_50_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_51.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_51_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_52.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_52_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_53.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_53_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_54.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_54_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_55.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_55_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_56.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_56_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_57.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_57_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_58.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_58_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_59.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_59_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_60.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_60_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_61.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_61_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_62.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_62_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_63.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_63_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_64.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_64_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_65.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_65_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_66.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_66_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_67.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_67_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_68.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_68_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_69.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_69_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_70.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_70_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_71.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_71_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_72.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_72_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_73.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_73_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_74.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_45/angle_74_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ...
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_330.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_330_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_331.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_331_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_332.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_332_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_333.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_333_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_334.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_334_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_335.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_335_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_336.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_336_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_337.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_337_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_338.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_338_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_339.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_339_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_340.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_340_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_341.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_341_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_342.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_342_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_343.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_343_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_344.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_344_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_345.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_345_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_346.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_346_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_347.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_347_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_348.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_348_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_349.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_349_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_350.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_350_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_351.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_351_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_352.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_352_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_353.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_353_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_354.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_354_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_355.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_355_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_356.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_356_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_357.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_357_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_358.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_358_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_359.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_359_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_360.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_360_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Augmenting cell 182
# Augmenting cell 183
# Augmenting cell 184
# Augmenting cell 185
# Augmenting cell 186
# Augmenting cell 187
# Augmenting cell 188
# Augmenting cell 189
# Augmenting cell 190
# Augmenting cell 191
# Augmenting cell 192
# Augmenting cell 193
# Augmenting cell 194
# Augmenting cell 195
# Augmenting cell 196
# Augmenting cell 197
# Augmenting cell 198
# Augmenting cell 199
