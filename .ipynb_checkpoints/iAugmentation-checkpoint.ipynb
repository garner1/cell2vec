# %%
import numpy as np
import os
import random
from scipy import ndarray
import skimage as sk
from skimage import transform
from skimage import util
from skimage import io
import imageio
import cv2

# %%
def random_rotation(image_array):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree)

def rotation(image_array, degree):
    return sk.transform.rotate(image_array, degree)

def random_noise(image_array):
    # add random noise to the image
    return sk.util.random_noise(image_array)

def horizontal_flip(image_array):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]

    return rmin, rmax, cmin, cmax    

def pad_with(vector, pad_width, iaxis, kwargs):
    pad_value = kwargs.get('padder', 0)
    vector[:pad_width[0]] = pad_value
    vector[-pad_width[1]:] = pad_value

def rotate_image(mat, angle):
    """
    Rotates an image (angle in degrees) and expands image to avoid cropping
    """

    height, width = mat.shape[:2] # image shape has 3 dimensions
    image_center = (width/2, height/2) # getRotationMatrix2D needs coordinates in reverse order (width, height) compared to shape

    rotation_mat = cv2.getRotationMatrix2D(image_center, angle, 1.)

    # rotation calculates the cos and sin, taking absolutes of those.
    abs_cos = abs(rotation_mat[0,0]) 
    abs_sin = abs(rotation_mat[0,1])

    # find the new width and height bounds
    bound_w = int(height * abs_sin + width * abs_cos)
    bound_h = int(height * abs_cos + width * abs_sin)

    # subtract old image center (bringing image back to origo) and adding the new image center coordinates
    rotation_mat[0, 2] += bound_w/2 - image_center[0]
    rotation_mat[1, 2] += bound_h/2 - image_center[1]

    # rotate image with the new bounds and translated rotation matrix
    rotated_mat = cv2.warpAffine(mat, rotation_mat, (bound_w, bound_h))
    return rotated_mat

def augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step):
    images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    for num_processed_cell in range(num_unique_cells):
        path = '%s/cell_%s' % (augmented_folder_path,num_processed_cell)
        if not os.path.isdir(path): 
            os.mkdir(path)
        else:
            pass

    for num_processed_cell in range(num_unique_cells):
        print('Augmenting cell '+str(num_processed_cell)+' in '+folder_path)
        image_path = images[num_processed_cell]
        image_path = imageio.imread(image_path)
        rmin, rmax, cmin, cmax = bbox(image_path)
        image_to_transform = np.pad(image_path[rmin:rmax,cmin:cmax], 2, pad_with, padder=0)  

        rotation_angle = 0
        transformed_image = None
        while rotation_angle < 360:
#             transformed_image = rotation(image_to_transform, rotation_angle)
            transformed_image = rotate_image(image_to_transform, rotation_angle)
            new_file_path = '%s/cell_%s/angle_%s.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
            io.imsave(new_file_path, transformed_image)
            transformed_image = horizontal_flip(transformed_image)
            new_file_path = '%s/cell_%s/angle_%s_flipped.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
            io.imsave(new_file_path, transformed_image)
            rotation_angle += angle_step

# %%
'''Generate for each of the unique cell type, all rotated and flipped copies. 
The usefulnes of this could be related to the possibility of connecting in the high dimensional space
images that would be otherwise sparsely displaced - curse of dimensionality - and difficult to cluster. 
It is a way of better sensing the low-dimensional manifold structure of the HD representation.'''

num_unique_cells = 200
angle_step = 1

# folder_path = '/home/garner1/Work/dataset/cellImages/training/Cancer'
# augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training_augmented/Cancer'
# augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step)

# folder_path = '/home/garner1/Work/dataset/cellImages/training/Immuno'
# augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training_augmented/Immuno'
# augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step)

# folder_path = '/home/garner1/Work/dataset/cellImages/training/Other'
# augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training_augmented/Other'
# augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step)

num_unique_cells = 1699
folder_path = '/home/garner1/Work/dataset/cellImages/image52/images'
augmented_folder_path = '/home/garner1/Work/dataset/cellImages/image52/augmented'
augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step)
# Out:
# Augmenting cell 0 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 2 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 3 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 4 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 5 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 6 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 7 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 8 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 9 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 10 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 11 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 12 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 13 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 14 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 15 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 16 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 17 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 18 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 19 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 20 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 21 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 22 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 23 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 24 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 25 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 26 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 27 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 28 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 29 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 30 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 31 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 32 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 33 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 34 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 35 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 36 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 37 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 38 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 39 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 40 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 41 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 42 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 43 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 44 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 45 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 46 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 47 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 48 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 49 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 50 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 51 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 52 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 53 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 54 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 55 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 56 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 57 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 58 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 59 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 60 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 61 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 62 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 63 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 64 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 65 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 66 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 67 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 68 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 69 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 70 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 71 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 72 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 73 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 74 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 75 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 76 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 77 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 78 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 79 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 80 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 81 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 82 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 83 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 84 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 85 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 86 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 87 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 88 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 89 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 90 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 91 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 92 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 93 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 94 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 95 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 96 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 97 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 98 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 99 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 100 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 101 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 102 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 103 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 104 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 105 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 106 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 107 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 108 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 109 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 110 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 111 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 112 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 113 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 114 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 115 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 116 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 117 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 118 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 119 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 120 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 121 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 122 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 123 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 124 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 125 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 126 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 127 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 128 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 129 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 130 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 131 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 132 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 133 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 134 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 135 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 136 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 137 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 138 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 139 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 140 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 141 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 142 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 143 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 144 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 145 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 146 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 147 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 148 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 149 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 150 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 151 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 152 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 153 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 154 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 155 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 156 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 157 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 158 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 159 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 160 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 161 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 162 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 163 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 164 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 165 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 166 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 167 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 168 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 169 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 170 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 171 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 172 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 173 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 174 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 175 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 176 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 177 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 178 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 179 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 180 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 181 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 182 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 183 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 184 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 185 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 186 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 187 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 188 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 189 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 190 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 191 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 192 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 193 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 194 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 195 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 196 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 197 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 198 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 199 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 200 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 201 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 202 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 203 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 204 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 205 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 206 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 207 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 208 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 209 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 210 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 211 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 212 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 213 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 214 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 215 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 216 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 217 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 218 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 219 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 220 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 221 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 222 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 223 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 224 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 225 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 226 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 227 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 228 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 229 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 230 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 231 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 232 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 233 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 234 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 235 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 236 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 237 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 238 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 239 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 240 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 241 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 242 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 243 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 244 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 245 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 246 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 247 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 248 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 249 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 250 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 251 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 252 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 253 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 254 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 255 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 256 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 257 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 258 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 259 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 260 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 261 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 262 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 263 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 264 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 265 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 266 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 267 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 268 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 269 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 270 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 271 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 272 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 273 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 274 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 275 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 276 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 277 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 278 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 279 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 280 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 281 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 282 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 283 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 284 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 285 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 286 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 287 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 288 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 289 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 290 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 291 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 292 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 293 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 294 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 295 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 296 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 297 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 298 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 299 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 300 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 301 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 302 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 303 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 304 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 305 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 306 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 307 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 308 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 309 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 310 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 311 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 312 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 313 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 314 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 315 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 316 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 317 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 318 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 319 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 320 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 321 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 322 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 323 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 324 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 325 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 326 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 327 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 328 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 329 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 330 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 331 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 332 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 333 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 334 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 335 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 336 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 337 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 338 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 339 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 340 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 341 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 342 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 343 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 344 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 345 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 346 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 347 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 348 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 349 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 350 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 351 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 352 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 353 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 354 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 355 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 356 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 357 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 358 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 359 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 360 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 361 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 362 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 363 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 364 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 365 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 366 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 367 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 368 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 369 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 370 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 371 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 372 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 373 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 374 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 375 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 376 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 377 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 378 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 379 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 380 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 381 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 382 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 383 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 384 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 385 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 386 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 387 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 388 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 389 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 390 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 391 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 392 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 393 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 394 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 395 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 396 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 397 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 398 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 399 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 400 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 401 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 402 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 403 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 404 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 405 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 406 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 407 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 408 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 409 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 410 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 411 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 412 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 413 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 414 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 415 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 416 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 417 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 418 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 419 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 420 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 421 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 422 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 423 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 424 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 425 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 426 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 427 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 428 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 429 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 430 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 431 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 432 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 433 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 434 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 435 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 436 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 437 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 438 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 439 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 440 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 441 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 442 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 443 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 444 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 445 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 446 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 447 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 448 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 449 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 450 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 451 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 452 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 453 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 454 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 455 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 456 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 457 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 458 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 459 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 460 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 461 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 462 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 463 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 464 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 465 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 466 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 467 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 468 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 469 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 470 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 471 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 472 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 473 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 474 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 475 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 476 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 477 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 478 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 479 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 480 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 481 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 482 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 483 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 484 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 485 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 486 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 487 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 488 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 489 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 490 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 491 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 492 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 493 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 494 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 495 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 496 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 497 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 498 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 499 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 500 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 501 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 502 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 503 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 504 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 505 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 506 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 507 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 508 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 509 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 510 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 511 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 512 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 513 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 514 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 515 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 516 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 517 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 518 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 519 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 520 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 521 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 522 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 523 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 524 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 525 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 526 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 527 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 528 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 529 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 530 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 531 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 532 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 533 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 534 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 535 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 536 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 537 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 538 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 539 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 540 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 541 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 542 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 543 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 544 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 545 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 546 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 547 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 548 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 549 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 550 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 551 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 552 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 553 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 554 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 555 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 556 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 557 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 558 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 559 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 560 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 561 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 562 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 563 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 564 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 565 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 566 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 567 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 568 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 569 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 570 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 571 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 572 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 573 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 574 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 575 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 576 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 577 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 578 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 579 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 580 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 581 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 582 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 583 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 584 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 585 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 586 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 587 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 588 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 589 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 590 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 591 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 592 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 593 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 594 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 595 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 596 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 597 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 598 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 599 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 600 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 601 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 602 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 603 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 604 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 605 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 606 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 607 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 608 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 609 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 610 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 611 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 612 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 613 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 614 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 615 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 616 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 617 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 618 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 619 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 620 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 621 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 622 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 623 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 624 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 625 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 626 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 627 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 628 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 629 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 630 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 631 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 632 in /home/garner1/Work/dataset/cellImages/image52/images
# ...
# Augmenting cell 1492 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1493 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1494 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1495 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1496 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1497 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1498 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1499 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1500 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1501 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1502 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1503 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1504 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1505 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1506 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1507 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1508 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1509 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1510 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1511 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1512 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1513 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1514 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1515 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1516 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1517 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1518 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1519 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1520 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1521 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1522 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1523 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1524 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1525 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1526 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1527 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1528 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1529 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1530 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1531 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1532 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1533 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1534 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1535 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1536 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1537 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1538 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1539 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1540 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1541 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1542 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1543 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1544 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1545 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1546 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1547 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1548 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1549 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1550 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1551 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1552 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1553 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1554 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1555 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1556 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1557 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1558 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1559 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1560 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1561 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1562 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1563 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1564 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1565 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1566 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1567 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1568 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1569 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1570 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1571 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1572 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1573 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1574 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1575 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1576 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1577 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1578 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1579 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1580 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1581 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1582 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1583 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1584 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1585 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1586 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1587 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1588 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1589 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1590 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1591 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1592 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1593 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1594 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1595 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1596 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1597 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1598 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1599 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1600 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1601 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1602 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1603 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1604 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1605 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1606 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1607 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1608 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1609 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1610 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1611 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1612 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1613 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1614 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1615 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1616 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1617 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1618 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1619 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1620 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1621 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1622 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1623 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1624 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1625 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1626 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1627 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1628 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1629 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1630 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1631 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1632 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1633 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1634 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1635 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1636 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1637 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1638 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1639 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1640 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1641 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1642 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1643 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1644 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1645 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1646 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1647 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1648 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1649 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1650 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1651 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1652 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1653 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1654 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1655 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1656 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1657 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1658 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1659 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1660 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1661 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1662 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1663 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1664 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1665 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1666 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1667 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1668 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1669 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1670 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1671 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1672 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1673 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1674 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1675 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1676 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1677 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1678 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1679 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1680 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1681 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1682 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1683 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1684 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1685 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1686 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1687 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1688 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1689 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1690 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1691 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1692 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1693 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1694 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1695 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1696 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1697 in /home/garner1/Work/dataset/cellImages/image52/images
# Augmenting cell 1698 in /home/garner1/Work/dataset/cellImages/image52/images
