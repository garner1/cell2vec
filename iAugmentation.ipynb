# %%
import numpy as np
import os
import random
from scipy import ndarray
import skimage as sk
from skimage import transform
from skimage import util
from skimage import io
import imageio

# %%
def random_rotation(image_array):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree)

def rotation(image_array, degree):
    return sk.transform.rotate(image_array, degree)

def random_noise(image_array):
    # add random noise to the image
    return sk.util.random_noise(image_array)

def horizontal_flip(image_array):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]

    return rmin, rmax, cmin, cmax    

def pad_with(vector, pad_width, iaxis, kwargs):
    pad_value = kwargs.get('padder', 0)
    vector[:pad_width[0]] = pad_value
    vector[-pad_width[1]:] = pad_value
    
def augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step):
    images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    for num_processed_cell in range(num_unique_cells):
        path = '%s/cell_%s' % (augmented_folder_path,num_processed_cell)
        if not os.path.isdir(path): 
            os.mkdir(path)
        else:
            pass

    for num_processed_cell in range(num_unique_cells):
        print('Augmenting cell '+str(num_processed_cell)+' in '+folder_path)
        image_path = images[num_processed_cell]
        image_path = imageio.imread(image_path)
        rmin, rmax, cmin, cmax = bbox(image_path)
        image_to_transform = np.pad(image_path[rmin:rmax,cmin:cmax], 2, pad_with, padder=0)  

        rotation_angle = 0
        transformed_image = None
        while rotation_angle <= 360:
            transformed_image = rotation(image_to_transform, rotation_angle)
            new_file_path = '%s/cell_%s/angle_%s.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
            io.imsave(new_file_path, transformed_image)
            transformed_image = horizontal_flip(transformed_image)
            new_file_path = '%s/cell_%s/angle_%s_flipped.jpg' % (augmented_folder_path,num_processed_cell,rotation_angle)
            io.imsave(new_file_path, transformed_image)
            rotation_angle += angle_step

# %%
'''Generate for each of the unique cell type, all rotated and flipped copies. 
The usefulnes of this could be related to the possibility of connecting in the high dimensional space
images that would be otherwise sparsely displaced - curse of dimensionality - and difficult to cluster. 
It is a way of better sensing the low-dimensional manifold structure of the HD representation.'''

num_unique_cells = 200
angle_step = 5

folder_path = '/home/garner1/Work/dataset/cellImages/training/Cancer'
augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training/augmented/Cancer'
augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step)

folder_path = '/home/garner1/Work/dataset/cellImages/training/Immuno'
augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training/augmented/Immuno'
augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step)

folder_path = '/home/garner1/Work/dataset/cellImages/training/Other'
augmented_folder_path = '/home/garner1/Work/dataset/cellImages/training/augmented/Other'
augmentation(folder_path,augmented_folder_path,num_unique_cells,angle_step)
# Out:
# Augmenting cell 0 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 1 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 2 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 3 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 4 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 5 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 6 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 7 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 8 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 9 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 10 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 11 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 12 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 13 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 14 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 15 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 16 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 17 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 18 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 19 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 20 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 21 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 22 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 23 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 24 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 25 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 26 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 27 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 28 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 29 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 30 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 31 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 32 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 33 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 34 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 35 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 36 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 37 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 38 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 39 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 40 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 41 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 42 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 43 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 44 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 45 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 46 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 47 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 48 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 49 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 50 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 51 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 52 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 53 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 54 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 55 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 56 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 57 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 58 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 59 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 60 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 61 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 62 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 63 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 64 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 65 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 66 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 67 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 68 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 69 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 70 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 71 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 72 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 73 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 74 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 75 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 76 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 77 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 78 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 79 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 80 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 81 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 82 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 83 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 84 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 85 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 86 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 87 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 88 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 89 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 90 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 91 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 92 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 93 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 94 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 95 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 96 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 97 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 98 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 99 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 100 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 101 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 102 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 103 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 104 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 105 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 106 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 107 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 108 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 109 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 110 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 111 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 112 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 113 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 114 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 115 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 116 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 117 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 118 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 119 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 120 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 121 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 122 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 123 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 124 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 125 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 126 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 127 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 128 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 129 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 130 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 131 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 132 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 133 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 134 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 135 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 136 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 137 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 138 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 139 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 140 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 141 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 142 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 143 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 144 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 145 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 146 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 147 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 148 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 149 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 150 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 151 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 152 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 153 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 154 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 155 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 156 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 157 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 158 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 159 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 160 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 161 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 162 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 163 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 164 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 165 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 166 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 167 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 168 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 169 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 170 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 171 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 172 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 173 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 174 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 175 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 176 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 177 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 178 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 179 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 180 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 181 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 182 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 183 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 184 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 185 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 186 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 187 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 188 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 189 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 190 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 191 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 192 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 193 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 194 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 195 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 196 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 197 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 198 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 199 in /home/garner1/Work/dataset/cellImages/training/Cancer
# Augmenting cell 0 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 1 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 2 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 3 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 4 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 5 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 6 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 7 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 8 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 9 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 10 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 11 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 12 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 13 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 14 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 15 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 16 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 17 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 18 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 19 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 20 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 21 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 22 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 23 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 24 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 25 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 26 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 27 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 28 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 29 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 30 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 31 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 32 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 33 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 34 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 35 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 36 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 37 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 38 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 39 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 40 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 41 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 42 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 43 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 44 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 45 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 46 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 47 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 48 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 49 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 50 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 51 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 52 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 53 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 54 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 55 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 56 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 57 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 58 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 59 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 60 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 61 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 62 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 63 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 64 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 65 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 66 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 67 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 68 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 69 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 70 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 71 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 72 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 73 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 74 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 75 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 76 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 77 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 78 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 79 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 80 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 81 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 82 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 83 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 84 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 85 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 86 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 87 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 88 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 89 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 90 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 91 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 92 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 93 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 94 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 95 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 96 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 97 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 98 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 99 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 100 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 101 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 102 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 103 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 104 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 105 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 106 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 107 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 108 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 109 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 110 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 111 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 112 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 113 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 114 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 115 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 116 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 117 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 118 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 119 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 120 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 121 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 122 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 123 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 124 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 125 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 126 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 127 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 128 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 129 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 130 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 131 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 132 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 133 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 134 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 135 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 136 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 137 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 138 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 139 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 140 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 141 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 142 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 143 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 144 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 145 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 146 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 147 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 148 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 149 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 150 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 151 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 152 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 153 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 154 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 155 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 156 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 157 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 158 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 159 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 160 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 161 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 162 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 163 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 164 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 165 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 166 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 167 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 168 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 169 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 170 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 171 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 172 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 173 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 174 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 175 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 176 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 177 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 178 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 179 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 180 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 181 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 182 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 183 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 184 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 185 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 186 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 187 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 188 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 189 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 190 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 191 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 192 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 193 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 194 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 195 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 196 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 197 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 198 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 199 in /home/garner1/Work/dataset/cellImages/training/Immuno
# Augmenting cell 0 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 1 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 2 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 3 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 4 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 5 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 6 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 7 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 8 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 9 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 10 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 11 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 12 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 13 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 14 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 15 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 16 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 17 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 18 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 19 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 20 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 21 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 22 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 23 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 24 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 25 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 26 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 27 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 28 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 29 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 30 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 31 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 32 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 33 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 34 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 35 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 36 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 37 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 38 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 39 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 40 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 41 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 42 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 43 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 44 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 45 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 46 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 47 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 48 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 49 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 50 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 51 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 52 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 53 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 54 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 55 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 56 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 57 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 58 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 59 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 60 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 61 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 62 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 63 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 64 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 65 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 66 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 67 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 68 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 69 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 70 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 71 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 72 in /home/garner1/Work/dataset/cellImages/training/Other
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_65.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_65_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_75.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_75_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_80.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_80_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_85.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_85_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_95.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_95_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_100.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_100_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_105.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_105_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_110.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_110_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_115.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_115_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_120.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_120_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_125.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_125_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_130.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_130_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_140.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_140_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_245.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_245_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_255.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_255_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_260.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_260_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_265.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_265_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_275.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_275_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_280.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_280_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_285.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_285_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_290.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_290_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_295.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_295_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_300.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_300_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_305.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_72/angle_305_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ...
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_215_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_220.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_220_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_225.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_225_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_230.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_230_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_235.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_235_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_240.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_240_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_245.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_245_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_250.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_250_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_255.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_255_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_260.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_260_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_265.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_265_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_270.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_270_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_275.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_275_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_280.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_280_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_285.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_285_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_290.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_290_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_295.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_295_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_300.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_300_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_305.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_305_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_310.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_310_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_315.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_315_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_320.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_320_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_325.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_325_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_330.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_330_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_335.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_335_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_340.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_340_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_345.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_345_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_350.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_350_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_355.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_355_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_360.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/share/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/garner1/Work/dataset/cellImages/training/augmented/Other/cell_181/angle_360_flipped.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Augmenting cell 184 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 185 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 186 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 187 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 188 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 189 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 190 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 191 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 192 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 193 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 194 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 195 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 196 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 197 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 198 in /home/garner1/Work/dataset/cellImages/training/Other
# Augmenting cell 199 in /home/garner1/Work/dataset/cellImages/training/Other
